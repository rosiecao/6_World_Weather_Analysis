# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
#!conda install -c conda-forge gmaps
#!pip install gmaps
# !pip install gmaps
# Out:
# Requirement already satisfied: gmaps in c:\users\heo\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: six in c:\users\heo\anaconda3\lib\site-packages (from gmaps) (1.15.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\heo\anaconda3\lib\site-packages (from gmaps) (7.22.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\heo\anaconda3\lib\site-packages (from gmaps) (7.6.3)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\heo\anaconda3\lib\site-packages (from gmaps) (5.0.5)
# Requirement already satisfied: geojson>=2.0.0 in c:\users\heo\anaconda3\lib\site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: decorator in c:\users\heo\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (5.0.6)
# Requirement already satisfied: jedi>=0.16 in c:\users\heo\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.17.2)
# Requirement already satisfied: backcall in c:\users\heo\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\heo\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (3.0.17)
# Requirement already satisfied: pickleshare in c:\users\heo\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\heo\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (52.0.0.post20210125)
# Requirement already satisfied: pygments in c:\users\heo\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (2.8.1)
# Requirement already satisfied: colorama in c:\users\heo\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.4)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\heo\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.3.4)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\heo\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\heo\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\heo\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: jupyter-client in c:\users\heo\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in c:\users\heo\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\heo\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: jupyter-core in c:\users\heo\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.7.1)
# Requirement already satisfied: ipython-genutils in c:\users\heo\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\heo\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\heo\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\heo\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.17.3)
# Requirement already satisfied: wcwidth in c:\users\heo\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\heo\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.3.0)
# Requirement already satisfied: jinja2 in c:\users\heo\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.3)
# Requirement already satisfied: pyzmq>=17 in c:\users\heo\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.0.0)
# Requirement already satisfied: prometheus-client in c:\users\heo\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.10.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\heo\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.9.4)
# Requirement already satisfied: nbconvert in c:\users\heo\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.7)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\heo\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: argon2-cffi in c:\users\heo\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.1.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\heo\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\heo\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (227)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\heo\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\heo\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\heo\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\heo\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\heo\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.3)
# Requirement already satisfied: defusedxml in c:\users\heo\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: testpath in c:\users\heo\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\heo\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\heo\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: bleach in c:\users\heo\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.3.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\heo\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\heo\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: async-generator in c:\users\heo\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\heo\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\heo\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: packaging in c:\users\heo\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.9)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\heo\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.4.7)

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config2 import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_Database.csv")
city_data_df.head()
# Out:
#    City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0       Orizona      BR -17.0314  -48.2958     90.64        34
# 1        1  Ponta Do Sol      PT  32.6667  -17.1000     76.71        57
# 2        2          Aban      RU  56.6700   96.0600     40.87        88
# 3        3        Albany      US  42.6001  -73.9662     47.48        83
# 4        4          Hilo      US  19.7297 -155.0900     73.27        91
#
#    Cloudiness  Wind Speed Current Description
# 0          95       12.12       moderate rain
# 1          15        5.14          few clouds
# 2         100       17.98          light rain
# 3           0        2.08           clear sky
# 4          90        0.00          light rain

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
print("Please enter a minimum and maximum temperature range for your ideal vacation.")
mintemp = float(input("Minimum: " ))
maxtemp = float(input("Maximum: "))
# Out:
# Please enter a minimum and maximum temperature range for your ideal vacation.
# Minimum: 60
# Maximum: 70

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.


preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] > mintemp)
                                         & (city_data_df["Max Temp"] < maxtemp)] 

 
preferred_cities_df.head()
# Out:
#     City_ID           City Country      Lat       Lng  Max Temp  Humidity  \
# 16       16    Port Alfred      ZA -33.5906   26.8910     63.16        61
# 22       22       Morehead      US  37.2711  -87.1764     65.14        82
# 27       27   Saint George      US  37.1041 -113.5841     60.53        51
# 34       34      Esperance      AU -33.8667  121.9000     69.64        38
# 44       44  Rabo De Peixe      PT  37.8000  -25.5833     67.51        64
#
#     Cloudiness  Wind Speed Current Description
# 16          45       10.27    scattered clouds
# 22          40        1.99    scattered clouds
# 27          99        3.65     overcast clouds
# 34         100       24.05     overcast clouds
# 44          20        9.22          few clouds

# %%
# 4a. Determine if there are any empty rows.

preferred_cities_df.count()
# Out:
# City_ID                94
# City                   94
# Country                93
# Lat                    94
# Lng                    94
# Max Temp               94
# Humidity               94
# Cloudiness             94
# Wind Speed             94
# Current Description    94
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
cleaned_preferred_cities_df = preferred_cities_df.dropna()
cleaned_preferred_cities_df.head()
# Out:
#     City_ID           City Country      Lat       Lng  Max Temp  Humidity  \
# 16       16    Port Alfred      ZA -33.5906   26.8910     63.16        61
# 22       22       Morehead      US  37.2711  -87.1764     65.14        82
# 27       27   Saint George      US  37.1041 -113.5841     60.53        51
# 34       34      Esperance      AU -33.8667  121.9000     69.64        38
# 44       44  Rabo De Peixe      PT  37.8000  -25.5833     67.51        64
#
#     Cloudiness  Wind Speed Current Description
# 16          45       10.27    scattered clouds
# 22          40        1.99    scattered clouds
# 27          99        3.65     overcast clouds
# 34         100       24.05     overcast clouds
# 44          20        9.22          few clouds

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = cleaned_preferred_cities_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()
# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#                City Country  Max Temp Current Description      Lat       Lng  \
# 16      Port Alfred      ZA     63.16    scattered clouds -33.5906   26.8910
# 22         Morehead      US     65.14    scattered clouds  37.2711  -87.1764
# 27     Saint George      US     60.53     overcast clouds  37.1041 -113.5841
# 34        Esperance      AU     69.64     overcast clouds -33.8667  121.9000
# 44    Rabo De Peixe      PT     67.51          few clouds  37.8000  -25.5833
# ..              ...     ...       ...                 ...      ...       ...
# 662           Avera      US     66.90     overcast clouds  33.1940  -82.5271
# 667         Kushima      JP     63.07     overcast clouds  31.4583  131.2333
# 669         Hualmay      PE     64.90       broken clouds -11.0964  -77.6139
# 674          Thames      NZ     61.38     overcast clouds -37.1333  175.5333
# 680  Virginia Beach      US     68.02    scattered clouds  36.8529  -75.9780
#
#     Hotel Name
# 16
# 22
# 27
# 34
# 44
# ..         ...
# 662
# 667
# 669
# 674
# 680
#
# [93 rows x 7 columns]

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.

    # 6c. Get latitude and longitude from DataFrame
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]
    
    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"
    
    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # 6d.  Set up the base URL for the Google Directions API to get JSON data
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name, if a hotel isn't found skip the city.
    
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df
# Out:
#                City Country  Max Temp Current Description      Lat       Lng  \
# 16      Port Alfred      ZA     63.16    scattered clouds -33.5906   26.8910
# 22         Morehead      US     65.14    scattered clouds  37.2711  -87.1764
# 27     Saint George      US     60.53     overcast clouds  37.1041 -113.5841
# 34        Esperance      AU     69.64     overcast clouds -33.8667  121.9000
# 44    Rabo De Peixe      PT     67.51          few clouds  37.8000  -25.5833
# ..              ...     ...       ...                 ...      ...       ...
# 662           Avera      US     66.90     overcast clouds  33.1940  -82.5271
# 667         Kushima      JP     63.07     overcast clouds  31.4583  131.2333
# 669         Hualmay      PE     64.90       broken clouds -11.0964  -77.6139
# 674          Thames      NZ     61.38     overcast clouds -37.1333  175.5333
# 680  Virginia Beach      US     68.02    scattered clouds  36.8529  -75.9780
#
#                            Hotel Name
# 16                 The Halyards Hotel
# 22                    CCI Express Inn
# 27        Best Western Plus Abbey Inn
# 34              Hospitality Esperance
# 44                 Quinta das Giestas
# ..                                ...
# 662
# 667                           Hanaoka
# 669         Hotel Villa Kitzia Huacho
# 674             Avalon Motel - Thames
# 680  Hilton Virginia Beach Oceanfront
#
# [93 rows x 7 columns]

# %%
# 7. Drop the rows where there is no Hotel Name.

# %%
# 8a. Create the output File (CSV)
output_data_file = "../Vacation_Search/WeatherPy_vacation.csv"

# 8b. Export the City_Data into a csv
hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """

"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = hotel_df[["Lat", "Lng"]]

# %%
# %matplotlib inline
# 11a. Add a marker layer for each city to the map. 
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig = gmaps.figure()


# 11b. Display the figure
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
