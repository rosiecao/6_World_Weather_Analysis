# %%
import requests

from config import weather_api_key

import time

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the random module.
import random

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
coordinates = zip(lats, lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=66eeb9bc54e1da485ca6943b628b6224

# %%
# Import the datetime module from the datetime library
from datetime import datetime
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

 
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    time.sleep(1)

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | orizona
# Processing Record 2 of Set 1 | ponta do sol
# Processing Record 3 of Set 1 | sedelnikovo
# City not found. Skipping...
# Processing Record 4 of Set 1 | aban
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | chokurdakh
# Processing Record 10 of Set 1 | viransehir
# Processing Record 11 of Set 1 | popondetta
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | ribeira grande
# Processing Record 16 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 1 | leningradskiy
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | mabaruma
# Processing Record 20 of Set 1 | tuktoyaktuk
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | villavicencio
# Processing Record 23 of Set 1 | olafsvik
# Processing Record 24 of Set 1 | nexo
# Processing Record 25 of Set 1 | beloha
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | morehead
# Processing Record 28 of Set 1 | victoria
# Processing Record 29 of Set 1 | paamiut
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | wanaka
# Processing Record 32 of Set 1 | saint george
# Processing Record 33 of Set 1 | chicama
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | mahebourg
# Processing Record 36 of Set 1 | nuqui
# Processing Record 37 of Set 1 | ijaki
# City not found. Skipping...
# Processing Record 38 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 1 | esperance
# Processing Record 43 of Set 1 | tuatapere
# Processing Record 44 of Set 1 | sarangani
# Processing Record 45 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 1 | barrow
# Processing Record 48 of Set 1 | okhotsk
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | nikolskoye
# Processing Record 1 of Set 2 | makhu
# Processing Record 2 of Set 2 | mar del plata
# Processing Record 3 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 2 | singaparna
# Processing Record 5 of Set 2 | rabo de peixe
# Processing Record 6 of Set 2 | shubarshi
# Processing Record 7 of Set 2 | gornopravdinsk
# Processing Record 8 of Set 2 | bluff
# Processing Record 9 of Set 2 | ancud
# Processing Record 10 of Set 2 | mehamn
# Processing Record 11 of Set 2 | atuona
# Processing Record 12 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 2 | carnarvon
# Processing Record 14 of Set 2 | zhigansk
# Processing Record 15 of Set 2 | salym
# Processing Record 16 of Set 2 | pitea
# Processing Record 17 of Set 2 | deputatskiy
# Processing Record 18 of Set 2 | cidreira
# Processing Record 19 of Set 2 | ushuaia
# Processing Record 20 of Set 2 | kogon
# Processing Record 21 of Set 2 | rorvik
# Processing Record 22 of Set 2 | itarema
# Processing Record 23 of Set 2 | the valley
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | busselton
# Processing Record 26 of Set 2 | rayagada
# Processing Record 27 of Set 2 | bredasdorp
# Processing Record 28 of Set 2 | ternate
# Processing Record 29 of Set 2 | salaberry-de-valleyfield
# Processing Record 30 of Set 2 | ponta delgada
# Processing Record 31 of Set 2 | boden
# Processing Record 32 of Set 2 | qaanaaq
# Processing Record 33 of Set 2 | new norfolk
# Processing Record 34 of Set 2 | kaitangata
# Processing Record 35 of Set 2 | brcko
# Processing Record 36 of Set 2 | narsaq
# Processing Record 37 of Set 2 | adrar
# Processing Record 38 of Set 2 | vaini
# Processing Record 39 of Set 2 | iralaya
# Processing Record 40 of Set 2 | lufilufi
# Processing Record 41 of Set 2 | isangel
# Processing Record 42 of Set 2 | ahipara
# Processing Record 43 of Set 2 | puerto ayora
# Processing Record 44 of Set 2 | kahului
# Processing Record 45 of Set 2 | hobart
# Processing Record 46 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 2 | caravelas
# Processing Record 49 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 2 | torbay
# Processing Record 1 of Set 3 | conde
# Processing Record 2 of Set 3 | yabelo
# Processing Record 3 of Set 3 | tiksi
# Processing Record 4 of Set 3 | sitka
# Processing Record 5 of Set 3 | port-cartier
# Processing Record 6 of Set 3 | provideniya
# Processing Record 7 of Set 3 | mataura
# Processing Record 8 of Set 3 | fort-shevchenko
# Processing Record 9 of Set 3 | lazaro cardenas
# Processing Record 10 of Set 3 | lavrentiya
# Processing Record 11 of Set 3 | mumford
# Processing Record 12 of Set 3 | yerbogachen
# Processing Record 13 of Set 3 | alofi
# Processing Record 14 of Set 3 | carmen
# Processing Record 15 of Set 3 | lebu
# Processing Record 16 of Set 3 | longyearbyen
# Processing Record 17 of Set 3 | khatanga
# Processing Record 18 of Set 3 | greenwood
# Processing Record 19 of Set 3 | banjar
# Processing Record 20 of Set 3 | zhitikara
# City not found. Skipping...
# Processing Record 21 of Set 3 | cockburn town
# Processing Record 22 of Set 3 | timiryazevskiy
# Processing Record 23 of Set 3 | kruisfontein
# Processing Record 24 of Set 3 | te anau
# Processing Record 25 of Set 3 | pringsewu
# Processing Record 26 of Set 3 | bambous virieux
# Processing Record 27 of Set 3 | chara
# Processing Record 28 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 3 | baki
# Processing Record 30 of Set 3 | huazolotitlan
# City not found. Skipping...
# Processing Record 31 of Set 3 | bethel
# Processing Record 32 of Set 3 | mount isa
# Processing Record 33 of Set 3 | vila franca do campo
# Processing Record 34 of Set 3 | abbeville
# Processing Record 35 of Set 3 | solovetskiy
# City not found. Skipping...
# Processing Record 36 of Set 3 | thinadhoo
# Processing Record 37 of Set 3 | harper
# Processing Record 38 of Set 3 | tugulym
# Processing Record 39 of Set 3 | asfi
# Processing Record 40 of Set 3 | yunjinghong
# City not found. Skipping...
# Processing Record 41 of Set 3 | tazmalt
# Processing Record 42 of Set 3 | port macquarie
# Processing Record 43 of Set 3 | san patricio
# Processing Record 44 of Set 3 | saint-philippe
# Processing Record 45 of Set 3 | severo-kurilsk
# Processing Record 46 of Set 3 | husavik
# Processing Record 47 of Set 3 | lopik
# Processing Record 48 of Set 3 | saint-joseph
# Processing Record 49 of Set 3 | yeletskiy
# City not found. Skipping...
# Processing Record 50 of Set 3 | fortuna
# Processing Record 1 of Set 4 | oranjestad
# Processing Record 2 of Set 4 | zaozerne
# Processing Record 3 of Set 4 | jamestown
# Processing Record 4 of Set 4 | makarov
# Processing Record 5 of Set 4 | haapiti
# Processing Record 6 of Set 4 | pevek
# Processing Record 7 of Set 4 | kapaa
# Processing Record 8 of Set 4 | port-gentil
# Processing Record 9 of Set 4 | cabadiangan
# Processing Record 10 of Set 4 | airai
# Processing Record 11 of Set 4 | castro
# Processing Record 12 of Set 4 | cherskiy
# Processing Record 13 of Set 4 | doaba
# Processing Record 14 of Set 4 | kampot
# Processing Record 15 of Set 4 | lagoa
# Processing Record 16 of Set 4 | sooke
# Processing Record 17 of Set 4 | troitsko-pechorsk
# Processing Record 18 of Set 4 | corinto
# Processing Record 19 of Set 4 | narva-joesuu
# Processing Record 20 of Set 4 | brodokalmak
# Processing Record 21 of Set 4 | upernavik
# Processing Record 22 of Set 4 | lata
# Processing Record 23 of Set 4 | geraldton
# Processing Record 24 of Set 4 | kidal
# Processing Record 25 of Set 4 | ola
# Processing Record 26 of Set 4 | marathon
# Processing Record 27 of Set 4 | mulchen
# Processing Record 28 of Set 4 | stillwater
# Processing Record 29 of Set 4 | rio gallegos
# Processing Record 30 of Set 4 | karratha
# Processing Record 31 of Set 4 | creel
# Processing Record 32 of Set 4 | svetlogorsk
# Processing Record 33 of Set 4 | mlowo
# Processing Record 34 of Set 4 | moerai
# Processing Record 35 of Set 4 | seminole
# Processing Record 36 of Set 4 | congonhas
# Processing Record 37 of Set 4 | aklavik
# Processing Record 38 of Set 4 | lorengau
# Processing Record 39 of Set 4 | broome
# Processing Record 40 of Set 4 | srednekolymsk
# Processing Record 41 of Set 4 | korla
# Processing Record 42 of Set 4 | kodiak
# Processing Record 43 of Set 4 | tombouctou
# Processing Record 44 of Set 4 | mitsamiouli
# Processing Record 45 of Set 4 | namibe
# Processing Record 46 of Set 4 | havre
# Processing Record 47 of Set 4 | gat
# Processing Record 48 of Set 4 | faya
# Processing Record 49 of Set 4 | east london
# Processing Record 50 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 5 | sabana de torres
# Processing Record 3 of Set 5 | boyolangu
# Processing Record 4 of Set 5 | vyyezdnoye
# Processing Record 5 of Set 5 | cabo san lucas
# Processing Record 6 of Set 5 | necochea
# Processing Record 7 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 5 | george town
# Processing Record 9 of Set 5 | ajdabiya
# Processing Record 10 of Set 5 | port elizabeth
# Processing Record 11 of Set 5 | leshukonskoye
# Processing Record 12 of Set 5 | garowe
# Processing Record 13 of Set 5 | jalu
# Processing Record 14 of Set 5 | shache
# Processing Record 15 of Set 5 | motygino
# Processing Record 16 of Set 5 | ourossogui
# Processing Record 17 of Set 5 | ranong
# Processing Record 18 of Set 5 | willowmore
# Processing Record 19 of Set 5 | rudbar
# Processing Record 20 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 21 of Set 5 | bilma
# Processing Record 22 of Set 5 | medveditskiy
# Processing Record 23 of Set 5 | pisco
# Processing Record 24 of Set 5 | arcata
# Processing Record 25 of Set 5 | wicklow
# Processing Record 26 of Set 5 | nenjiang
# Processing Record 27 of Set 5 | nanortalik
# Processing Record 28 of Set 5 | viedma
# Processing Record 29 of Set 5 | beringovskiy
# Processing Record 30 of Set 5 | kismayo
# Processing Record 31 of Set 5 | los llanos de aridane
# Processing Record 32 of Set 5 | store heddinge
# Processing Record 33 of Set 5 | vostok
# Processing Record 34 of Set 5 | nador
# Processing Record 35 of Set 5 | shahrud
# Processing Record 36 of Set 5 | la ronge
# Processing Record 37 of Set 5 | san juan
# Processing Record 38 of Set 5 | kaseda
# Processing Record 39 of Set 5 | malia
# Processing Record 40 of Set 5 | abu samrah
# Processing Record 41 of Set 5 | marrakesh
# Processing Record 42 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 5 | safaga
# Processing Record 44 of Set 5 | nishiwaki
# Processing Record 45 of Set 5 | panguipulli
# Processing Record 46 of Set 5 | lucea
# Processing Record 47 of Set 5 | khandbari
# Processing Record 48 of Set 5 | salalah
# Processing Record 49 of Set 5 | kiunga
# Processing Record 50 of Set 5 | zhaocheng
# City not found. Skipping...
# Processing Record 1 of Set 6 | hofn
# Processing Record 2 of Set 6 | la plata
# Processing Record 3 of Set 6 | guerrero negro
# Processing Record 4 of Set 6 | liuzhou
# Processing Record 5 of Set 6 | kamenka
# Processing Record 6 of Set 6 | muyezerskiy
# Processing Record 7 of Set 6 | yulara
# Processing Record 8 of Set 6 | pathein
# Processing Record 9 of Set 6 | padang
# Processing Record 10 of Set 6 | teguldet
# Processing Record 11 of Set 6 | fuerte olimpo
# Processing Record 12 of Set 6 | dasoguz
# Processing Record 13 of Set 6 | salinopolis
# Processing Record 14 of Set 6 | meadow lake
# Processing Record 15 of Set 6 | fort dodge
# Processing Record 16 of Set 6 | stupava
# Processing Record 17 of Set 6 | great falls
# Processing Record 18 of Set 6 | antalaha
# Processing Record 19 of Set 6 | sao filipe
# Processing Record 20 of Set 6 | kenora
# Processing Record 21 of Set 6 | vila velha
# Processing Record 22 of Set 6 | vanavara
# Processing Record 23 of Set 6 | luderitz
# Processing Record 24 of Set 6 | mizdah
# Processing Record 25 of Set 6 | yanaul
# Processing Record 26 of Set 6 | thompson
# Processing Record 27 of Set 6 | lasa
# Processing Record 28 of Set 6 | lincoln
# Processing Record 29 of Set 6 | baherden
# Processing Record 30 of Set 6 | chissamba
# Processing Record 31 of Set 6 | teknaf
# Processing Record 32 of Set 6 | katsuura
# Processing Record 33 of Set 6 | santa cruz
# Processing Record 34 of Set 6 | tessalit
# Processing Record 35 of Set 6 | doda
# Processing Record 36 of Set 6 | bengkulu
# Processing Record 37 of Set 6 | belmonte
# Processing Record 38 of Set 6 | tambura
# Processing Record 39 of Set 6 | cascais
# Processing Record 40 of Set 6 | at-bashi
# Processing Record 41 of Set 6 | arkhangelsk
# Processing Record 42 of Set 6 | pedernales
# Processing Record 43 of Set 6 | watsa
# Processing Record 44 of Set 6 | santa rosa
# Processing Record 45 of Set 6 | tual
# Processing Record 46 of Set 6 | sakata
# Processing Record 47 of Set 6 | ardistan
# City not found. Skipping...
# Processing Record 48 of Set 6 | charlestown
# Processing Record 49 of Set 6 | honiara
# Processing Record 50 of Set 6 | santiago del estero
# Processing Record 1 of Set 7 | chkalovsk
# Processing Record 2 of Set 7 | bandarbeyla
# Processing Record 3 of Set 7 | rawson
# Processing Record 4 of Set 7 | poso
# Processing Record 5 of Set 7 | gacko
# Processing Record 6 of Set 7 | grindavik
# Processing Record 7 of Set 7 | tirumala
# Processing Record 8 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 7 | kabare
# Processing Record 10 of Set 7 | pokhara
# Processing Record 11 of Set 7 | itacoatiara
# Processing Record 12 of Set 7 | komsomolskiy
# Processing Record 13 of Set 7 | clyde river
# Processing Record 14 of Set 7 | shingu
# Processing Record 15 of Set 7 | bulungu
# Processing Record 16 of Set 7 | dezful
# Processing Record 17 of Set 7 | kendari
# Processing Record 18 of Set 7 | alihe
# Processing Record 19 of Set 7 | tasiilaq
# Processing Record 20 of Set 7 | stornoway
# Processing Record 21 of Set 7 | kavaratti
# Processing Record 22 of Set 7 | muisne
# Processing Record 23 of Set 7 | hope
# Processing Record 24 of Set 7 | irtyshskiy
# Processing Record 25 of Set 7 | saskylakh
# Processing Record 26 of Set 7 | dunedin
# Processing Record 27 of Set 7 | krasnoselkup
# Processing Record 28 of Set 7 | sabang
# Processing Record 29 of Set 7 | umm kaddadah
# Processing Record 30 of Set 7 | kiama
# Processing Record 31 of Set 7 | kavieng
# Processing Record 32 of Set 7 | ravar
# Processing Record 33 of Set 7 | yambio
# Processing Record 34 of Set 7 | kuroiso
# Processing Record 35 of Set 7 | hasaki
# Processing Record 36 of Set 7 | peniche
# Processing Record 37 of Set 7 | barcelona
# Processing Record 38 of Set 7 | alta floresta
# Processing Record 39 of Set 7 | dubbo
# Processing Record 40 of Set 7 | bartlesville
# Processing Record 41 of Set 7 | hambantota
# Processing Record 42 of Set 7 | iqaluit
# Processing Record 43 of Set 7 | poindimie
# Processing Record 44 of Set 7 | leua
# Processing Record 45 of Set 7 | angoche
# Processing Record 46 of Set 7 | zhangye
# Processing Record 47 of Set 7 | saint-augustin
# Processing Record 48 of Set 7 | chuy
# Processing Record 49 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 7 | kirn
# Processing Record 1 of Set 8 | camapua
# Processing Record 2 of Set 8 | acapulco
# Processing Record 3 of Set 8 | tastur
# Processing Record 4 of Set 8 | phu ly
# Processing Record 5 of Set 8 | sola
# Processing Record 6 of Set 8 | morros
# Processing Record 7 of Set 8 | quepos
# Processing Record 8 of Set 8 | mackenzie
# Processing Record 9 of Set 8 | tazovskiy
# Processing Record 10 of Set 8 | trat
# Processing Record 11 of Set 8 | muskegon
# Processing Record 12 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 8 | oranjemund
# Processing Record 14 of Set 8 | klaksvik
# Processing Record 15 of Set 8 | sheridan
# Processing Record 16 of Set 8 | san policarpo
# Processing Record 17 of Set 8 | floro
# Processing Record 18 of Set 8 | hovd
# Processing Record 19 of Set 8 | ust-shonosha
# Processing Record 20 of Set 8 | takoradi
# Processing Record 21 of Set 8 | vitim
# Processing Record 22 of Set 8 | didi lilo
# Processing Record 23 of Set 8 | chudniv
# Processing Record 24 of Set 8 | zwedru
# Processing Record 25 of Set 8 | agadir
# Processing Record 26 of Set 8 | krasne
# Processing Record 27 of Set 8 | neuquen
# Processing Record 28 of Set 8 | vardo
# Processing Record 29 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 8 | kiruna
# Processing Record 31 of Set 8 | kokkinon
# City not found. Skipping...
# Processing Record 32 of Set 8 | sao joao da barra
# Processing Record 33 of Set 8 | tam ky
# Processing Record 34 of Set 8 | ilesha
# Processing Record 35 of Set 8 | pahrump
# Processing Record 36 of Set 8 | flinders
# Processing Record 37 of Set 8 | rio linda
# Processing Record 38 of Set 8 | georgetown
# Processing Record 39 of Set 8 | moroni
# Processing Record 40 of Set 8 | hervey bay
# Processing Record 41 of Set 8 | altamira
# Processing Record 42 of Set 8 | lillesand
# Processing Record 43 of Set 8 | zalantun
# Processing Record 44 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 8 | anchorage
# Processing Record 46 of Set 8 | mount gambier
# Processing Record 47 of Set 8 | trofors
# Processing Record 48 of Set 8 | aykhal
# Processing Record 49 of Set 8 | mechoacan
# City not found. Skipping...
# Processing Record 50 of Set 8 | kundiawa
# Processing Record 1 of Set 9 | sal rei
# Processing Record 2 of Set 9 | parras
# City not found. Skipping...
# Processing Record 3 of Set 9 | agadez
# Processing Record 4 of Set 9 | wajima
# Processing Record 5 of Set 9 | predivinsk
# Processing Record 6 of Set 9 | sheregesh
# Processing Record 7 of Set 9 | taikang
# Processing Record 8 of Set 9 | asosa
# Processing Record 9 of Set 9 | svetlaya
# Processing Record 10 of Set 9 | saldanha
# Processing Record 11 of Set 9 | gradsko
# Processing Record 12 of Set 9 | bradulet
# Processing Record 13 of Set 9 | birobidzhan
# Processing Record 14 of Set 9 | linshu
# City not found. Skipping...
# Processing Record 15 of Set 9 | loei
# Processing Record 16 of Set 9 | anori
# Processing Record 17 of Set 9 | balikpapan
# Processing Record 18 of Set 9 | lucapa
# Processing Record 19 of Set 9 | kununurra
# Processing Record 20 of Set 9 | zhuhai
# Processing Record 21 of Set 9 | amiens
# Processing Record 22 of Set 9 | vallenar
# Processing Record 23 of Set 9 | codrington
# Processing Record 24 of Set 9 | bolgar
# Processing Record 25 of Set 9 | dingle
# Processing Record 26 of Set 9 | ulverstone
# Processing Record 27 of Set 9 | aswan
# Processing Record 28 of Set 9 | haines junction
# Processing Record 29 of Set 9 | half moon bay
# Processing Record 30 of Set 9 | the pas
# Processing Record 31 of Set 9 | fare
# Processing Record 32 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 33 of Set 9 | faanui
# Processing Record 34 of Set 9 | tynda
# Processing Record 35 of Set 9 | basco
# Processing Record 36 of Set 9 | suntar
# Processing Record 37 of Set 9 | waslala
# Processing Record 38 of Set 9 | nuevo laredo
# Processing Record 39 of Set 9 | nabinagar
# Processing Record 40 of Set 9 | yudong
# Processing Record 41 of Set 9 | jiuquan
# Processing Record 42 of Set 9 | marsh harbour
# Processing Record 43 of Set 9 | marzuq
# Processing Record 44 of Set 9 | lengshuitan
# Processing Record 45 of Set 9 | makakilo city
# Processing Record 46 of Set 9 | tsuyama
# Processing Record 47 of Set 9 | cap malheureux
# Processing Record 48 of Set 9 | mountain home
# Processing Record 49 of Set 9 | ostrovnoy
# Processing Record 50 of Set 9 | san quintin
# Processing Record 1 of Set 10 | real
# Processing Record 2 of Set 10 | port hedland
# Processing Record 3 of Set 10 | margate
# Processing Record 4 of Set 10 | ilka
# City not found. Skipping...
# Processing Record 5 of Set 10 | gizo
# Processing Record 6 of Set 10 | verkhoyansk
# Processing Record 7 of Set 10 | zhezkazgan
# Processing Record 8 of Set 10 | adana
# Processing Record 9 of Set 10 | kattivakkam
# Processing Record 10 of Set 10 | olavarria
# Processing Record 11 of Set 10 | taoudenni
# Processing Record 12 of Set 10 | berlevag
# Processing Record 13 of Set 10 | kjollefjord
# Processing Record 14 of Set 10 | sohag
# Processing Record 15 of Set 10 | tonj
# Processing Record 16 of Set 10 | launceston
# Processing Record 17 of Set 10 | lalmohan
# Processing Record 18 of Set 10 | nhulunbuy
# Processing Record 19 of Set 10 | ilulissat
# Processing Record 20 of Set 10 | cuitlahuac
# Processing Record 21 of Set 10 | gravdal
# Processing Record 22 of Set 10 | coquimbo
# Processing Record 23 of Set 10 | san carlos de bariloche
# Processing Record 24 of Set 10 | vila
# Processing Record 25 of Set 10 | souillac
# Processing Record 26 of Set 10 | dyurtyuli
# Processing Record 27 of Set 10 | nuuk
# Processing Record 28 of Set 10 | bathsheba
# Processing Record 29 of Set 10 | batagay
# Processing Record 30 of Set 10 | ojinaga
# Processing Record 31 of Set 10 | smithers
# Processing Record 32 of Set 10 | denpasar
# Processing Record 33 of Set 10 | norman wells
# Processing Record 34 of Set 10 | bubaque
# Processing Record 35 of Set 10 | bhinga
# Processing Record 36 of Set 10 | skibbereen
# Processing Record 37 of Set 10 | udachnyy
# Processing Record 38 of Set 10 | noumea
# Processing Record 39 of Set 10 | sampit
# Processing Record 40 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 41 of Set 10 | lompoc
# Processing Record 42 of Set 10 | kayankulam
# Processing Record 43 of Set 10 | kieta
# Processing Record 44 of Set 10 | yeppoon
# Processing Record 45 of Set 10 | asekeyevo
# Processing Record 46 of Set 10 | anju
# Processing Record 47 of Set 10 | grand gaube
# Processing Record 48 of Set 10 | storforshei
# Processing Record 49 of Set 10 | nong ki
# Processing Record 50 of Set 10 | nome
# Processing Record 1 of Set 11 | bhag
# Processing Record 2 of Set 11 | bull savanna
# Processing Record 3 of Set 11 | queanbeyan
# Processing Record 4 of Set 11 | talnakh
# Processing Record 5 of Set 11 | kurchum
# Processing Record 6 of Set 11 | villa bruzual
# Processing Record 7 of Set 11 | santa cruz del sur
# Processing Record 8 of Set 11 | araouane
# Processing Record 9 of Set 11 | khartoum
# Processing Record 10 of Set 11 | skierniewice
# Processing Record 11 of Set 11 | zhongshu
# Processing Record 12 of Set 11 | buraydah
# Processing Record 13 of Set 11 | sur
# Processing Record 14 of Set 11 | bocaranga
# City not found. Skipping...
# Processing Record 15 of Set 11 | barongis
# Processing Record 16 of Set 11 | ambilobe
# Processing Record 17 of Set 11 | fairbanks
# Processing Record 18 of Set 11 | praia da vitoria
# Processing Record 19 of Set 11 | kondinskoye
# Processing Record 20 of Set 11 | broken hill
# Processing Record 21 of Set 11 | nisia floresta
# Processing Record 22 of Set 11 | axim
# Processing Record 23 of Set 11 | mareeba
# Processing Record 24 of Set 11 | kitob
# Processing Record 25 of Set 11 | el arenal
# Processing Record 26 of Set 11 | santa cruz del norte
# Processing Record 27 of Set 11 | north platte
# Processing Record 28 of Set 11 | phon
# Processing Record 29 of Set 11 | namatanai
# Processing Record 30 of Set 11 | luhyny
# Processing Record 31 of Set 11 | tateyama
# Processing Record 32 of Set 11 | bara
# Processing Record 33 of Set 11 | saryozek
# Processing Record 34 of Set 11 | galdar
# Processing Record 35 of Set 11 | rio de janeiro
# Processing Record 36 of Set 11 | nara
# Processing Record 37 of Set 11 | beja
# Processing Record 38 of Set 11 | knysna
# Processing Record 39 of Set 11 | biak
# Processing Record 40 of Set 11 | sfantu gheorghe
# Processing Record 41 of Set 11 | alice springs
# Processing Record 42 of Set 11 | guarapari
# Processing Record 43 of Set 11 | molina
# Processing Record 44 of Set 11 | samut sakhon
# Processing Record 45 of Set 11 | grande-riviere
# City not found. Skipping...
# Processing Record 46 of Set 11 | sorland
# Processing Record 47 of Set 11 | tadine
# Processing Record 48 of Set 11 | ulaangom
# Processing Record 49 of Set 11 | muros
# Processing Record 50 of Set 11 | amapala
# Processing Record 1 of Set 12 | bo phloi
# Processing Record 2 of Set 12 | egvekinot
# Processing Record 3 of Set 12 | shupiyan
# Processing Record 4 of Set 12 | fenoarivo
# Processing Record 5 of Set 12 | yarovoye
# Processing Record 6 of Set 12 | shchelyayur
# City not found. Skipping...
# Processing Record 7 of Set 12 | itoman
# Processing Record 8 of Set 12 | lakes entrance
# Processing Record 9 of Set 12 | gilazi
# City not found. Skipping...
# Processing Record 10 of Set 12 | pitimbu
# Processing Record 11 of Set 12 | laguna
# Processing Record 12 of Set 12 | verkhnevilyuysk
# Processing Record 13 of Set 12 | kyren
# Processing Record 14 of Set 12 | portland
# Processing Record 15 of Set 12 | semporna
# Processing Record 16 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 17 of Set 12 | riberalta
# Processing Record 18 of Set 12 | atasu
# Processing Record 19 of Set 12 | gushikawa
# Processing Record 20 of Set 12 | yamada
# Processing Record 21 of Set 12 | prestea
# Processing Record 22 of Set 12 | upata
# Processing Record 23 of Set 12 | grand-santi
# Processing Record 24 of Set 12 | atbasar
# Processing Record 25 of Set 12 | qaqortoq
# Processing Record 26 of Set 12 | kasongo-lunda
# Processing Record 27 of Set 12 | stromness
# Processing Record 28 of Set 12 | cayenne
# Processing Record 29 of Set 12 | riverton
# Processing Record 30 of Set 12 | shihezi
# Processing Record 31 of Set 12 | keshan
# City not found. Skipping...
# Processing Record 32 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 33 of Set 12 | palmer
# Processing Record 34 of Set 12 | plymouth
# Processing Record 35 of Set 12 | kilindoni
# Processing Record 36 of Set 12 | statesboro
# Processing Record 37 of Set 12 | giddalur
# Processing Record 38 of Set 12 | salinas
# Processing Record 39 of Set 12 | timbiqui
# Processing Record 40 of Set 12 | quilali
# Processing Record 41 of Set 12 | ahuimanu
# Processing Record 42 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 12 | neder vindinge
# Processing Record 44 of Set 12 | antofagasta
# Processing Record 45 of Set 12 | alexandria
# Processing Record 46 of Set 12 | singaraja
# Processing Record 47 of Set 12 | luwingu
# Processing Record 48 of Set 12 | moose factory
# Processing Record 49 of Set 12 | texarkana
# Processing Record 50 of Set 12 | tromso
# Processing Record 1 of Set 13 | asau
# Processing Record 2 of Set 13 | jumla
# Processing Record 3 of Set 13 | mayumba
# Processing Record 4 of Set 13 | kisangani
# Processing Record 5 of Set 13 | miramar
# Processing Record 6 of Set 13 | dawlatabad
# Processing Record 7 of Set 13 | trincomalee
# Processing Record 8 of Set 13 | atar
# Processing Record 9 of Set 13 | acaponeta
# Processing Record 10 of Set 13 | maniitsoq
# Processing Record 11 of Set 13 | fukue
# Processing Record 12 of Set 13 | ladnun
# Processing Record 13 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 14 of Set 13 | musiri
# Processing Record 15 of Set 13 | quatre cocos
# Processing Record 16 of Set 13 | trairi
# Processing Record 17 of Set 13 | mae sai
# Processing Record 18 of Set 13 | uglovskoye
# Processing Record 19 of Set 13 | port hawkesbury
# Processing Record 20 of Set 13 | pine bluff
# Processing Record 21 of Set 13 | cachoeira do sul
# Processing Record 22 of Set 13 | kourou
# Processing Record 23 of Set 13 | saint-louis
# Processing Record 24 of Set 13 | ulagan
# Processing Record 25 of Set 13 | santa ana
# Processing Record 26 of Set 13 | nsanje
# Processing Record 27 of Set 13 | cururupu
# Processing Record 28 of Set 13 | nadezhda
# Processing Record 29 of Set 13 | majitha
# Processing Record 30 of Set 13 | karakol
# Processing Record 31 of Set 13 | vega de alatorre
# Processing Record 32 of Set 13 | manta
# Processing Record 33 of Set 13 | ciudad guayana
# Processing Record 34 of Set 13 | blagoyevo
# Processing Record 35 of Set 13 | aras
# Processing Record 36 of Set 13 | riyadh
# Processing Record 37 of Set 13 | inuvik
# Processing Record 38 of Set 13 | constitucion
# Processing Record 39 of Set 13 | pakxan
# Processing Record 40 of Set 13 | quesnel
# Processing Record 41 of Set 13 | mayo
# Processing Record 42 of Set 13 | golkoy
# Processing Record 43 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 44 of Set 13 | svecha
# Processing Record 45 of Set 13 | sapa
# Processing Record 46 of Set 13 | lima
# Processing Record 47 of Set 13 | tahoua
# Processing Record 48 of Set 13 | ibaiti
# Processing Record 49 of Set 13 | kalabo
# Processing Record 50 of Set 13 | gerash
# Processing Record 1 of Set 14 | kobojango
# City not found. Skipping...
# Processing Record 2 of Set 14 | manggar
# Processing Record 3 of Set 14 | itaiba
# Processing Record 4 of Set 14 | bari sadri
# Processing Record 5 of Set 14 | qasigiannguit
# Processing Record 6 of Set 14 | katobu
# Processing Record 7 of Set 14 | ratnagiri
# Processing Record 8 of Set 14 | maragogi
# Processing Record 9 of Set 14 | saint-georges
# Processing Record 10 of Set 14 | derzhavinsk
# Processing Record 11 of Set 14 | ierapetra
# Processing Record 12 of Set 14 | erzin
# Processing Record 13 of Set 14 | kualakapuas
# Processing Record 14 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 15 of Set 14 | baykit
# Processing Record 16 of Set 14 | san cristobal
# Processing Record 17 of Set 14 | hami
# Processing Record 18 of Set 14 | mitha tiwana
# Processing Record 19 of Set 14 | sao joao de pirabas
# Processing Record 20 of Set 14 | sao felix do xingu
# Processing Record 21 of Set 14 | skovorodino
# Processing Record 22 of Set 14 | tres arroyos
# Processing Record 23 of Set 14 | siwani
# City not found. Skipping...
# Processing Record 24 of Set 14 | santa vitoria do palmar
# Processing Record 25 of Set 14 | karkal
# Processing Record 26 of Set 14 | north bend
# Processing Record 27 of Set 14 | cotonou
# Processing Record 28 of Set 14 | seydi
# Processing Record 29 of Set 14 | apac
# Processing Record 30 of Set 14 | reconquista
# Processing Record 31 of Set 14 | nanakuli
# Processing Record 32 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 33 of Set 14 | paraiso
# Processing Record 34 of Set 14 | san luis
# Processing Record 35 of Set 14 | khuzhir
# Processing Record 36 of Set 14 | presidencia roque saenz pena
# Processing Record 37 of Set 14 | premia de mar
# Processing Record 38 of Set 14 | bjornevatn
# Processing Record 39 of Set 14 | muravlenko
# Processing Record 40 of Set 14 | mpika
# Processing Record 41 of Set 14 | weyburn
# Processing Record 42 of Set 14 | port talbot
# Processing Record 43 of Set 14 | oskemen
# Processing Record 44 of Set 14 | vedasandur
# Processing Record 45 of Set 14 | el burrion
# Processing Record 46 of Set 14 | road town
# Processing Record 47 of Set 14 | masvingo
# Processing Record 48 of Set 14 | mount barker
# Processing Record 49 of Set 14 | tahe
# Processing Record 50 of Set 14 | tupelo
# Processing Record 1 of Set 15 | dosso
# Processing Record 2 of Set 15 | koboldo
# City not found. Skipping...
# Processing Record 3 of Set 15 | mezen
# Processing Record 4 of Set 15 | forbes
# Processing Record 5 of Set 15 | yar-sale
# Processing Record 6 of Set 15 | bud
# Processing Record 7 of Set 15 | tsiroanomandidy
# Processing Record 8 of Set 15 | sayyan
# Processing Record 9 of Set 15 | pacific grove
# Processing Record 10 of Set 15 | pasni
# Processing Record 11 of Set 15 | houlton
# Processing Record 12 of Set 15 | listvyanka
# Processing Record 13 of Set 15 | archidona
# Processing Record 14 of Set 15 | iquitos
# Processing Record 15 of Set 15 | saint-denis
# Processing Record 16 of Set 15 | benalla
# Processing Record 17 of Set 15 | anadyr
# Processing Record 18 of Set 15 | avera
# Processing Record 19 of Set 15 | dali
# Processing Record 20 of Set 15 | traverse city
# Processing Record 21 of Set 15 | pontianak
# Processing Record 22 of Set 15 | sagua de tanamo
# Processing Record 23 of Set 15 | kushima
# Processing Record 24 of Set 15 | trzcianka
# Processing Record 25 of Set 15 | hualmay
# Processing Record 26 of Set 15 | yumen
# Processing Record 27 of Set 15 | lagos
# Processing Record 28 of Set 15 | havre-saint-pierre
# Processing Record 29 of Set 15 | governador valadares
# Processing Record 30 of Set 15 | thames
# Processing Record 31 of Set 15 | hobyo
# Processing Record 32 of Set 15 | hokitika
# Processing Record 33 of Set 15 | chistogorskiy
# Processing Record 34 of Set 15 | atmakur
# Processing Record 35 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 36 of Set 15 | havoysund
# Processing Record 37 of Set 15 | virginia beach
# Processing Record 38 of Set 15 | raton
# Processing Record 39 of Set 15 | orcopampa
# Processing Record 40 of Set 15 | burns lake
# Processing Record 41 of Set 15 | afgoye
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Orizona -17.0314  -48.2958     90.64        34          95
# 1  Ponta Do Sol  32.6667  -17.1000     76.71        57          15
# 2          Aban  56.6700   96.0600     40.87        88         100
# 3        Albany  42.6001  -73.9662     47.48        83           0
# 4          Hilo  19.7297 -155.0900     73.27        91          90
# 5    Chokurdakh  70.6333  147.9167    -13.43       100          96
# 6    Viransehir  37.2353   39.7631     74.73        12           5
# 7    Popondetta  -8.7537  148.2534     73.47        87          17
# 8     Cape Town -33.9258   18.4232     71.11        37           0
# 9   Yellowknife  62.4560 -114.3525     42.42        85          90
#
#    Wind Speed Country                 Date Current Description
# 0       12.12      BR  2021-10-24 13:57:21       moderate rain
# 1        5.14      PT  2021-10-24 13:57:23          few clouds
# 2       17.98      RU  2021-10-24 13:57:25          light rain
# 3        2.08      US  2021-10-24 13:57:27           clear sky
# 4        0.00      US  2021-10-24 13:57:30          light rain
# 5        3.36      RU  2021-10-24 13:57:31     overcast clouds
# 6        6.82      TR  2021-10-24 13:57:32           clear sky
# 7        3.38      PG  2021-10-24 13:57:34          few clouds
# 8        4.00      ZA  2021-10-24 13:56:19           clear sky
# 9       19.57      CA  2021-10-24 13:57:36     overcast clouds

# %%
# Reorder the columns 
new_column_order = ["City", "Country", "Lat",
                   "Lng", "Max Temp", "Humidity",
                   "Cloudiness", "Wind Speed",
                   "Current Description"]
# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Orizona      BR -17.0314  -48.2958     90.64        34          95
# 1  Ponta Do Sol      PT  32.6667  -17.1000     76.71        57          15
# 2          Aban      RU  56.6700   96.0600     40.87        88         100
# 3        Albany      US  42.6001  -73.9662     47.48        83           0
# 4          Hilo      US  19.7297 -155.0900     73.27        91          90
# 5    Chokurdakh      RU  70.6333  147.9167    -13.43       100          96
# 6    Viransehir      TR  37.2353   39.7631     74.73        12           5
# 7    Popondetta      PG  -8.7537  148.2534     73.47        87          17
# 8     Cape Town      ZA -33.9258   18.4232     71.11        37           0
# 9   Yellowknife      CA  62.4560 -114.3525     42.42        85          90
#
#    Wind Speed Current Description
# 0       12.12       moderate rain
# 1        5.14          few clouds
# 2       17.98          light rain
# 3        2.08           clear sky
# 4        0.00          light rain
# 5        3.36     overcast clouds
# 6        6.82           clear sky
# 7        3.38          few clouds
# 8        4.00           clear sky
# 9       19.57     overcast clouds

# %%
# Export DataFrame as WeatherPy_Database.csv into Weather_Database folder
# create the output file (CSV)
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
